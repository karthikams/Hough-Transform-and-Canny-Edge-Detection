# %%
import cv2
from  matplotlib import pyplot as plt

# %%
'''
Loading file
'''
img = cv2.imread("C:/Users/Kathu/Desktop/SJSU/Second Sem/ML - CMPE 257/Python files/Lane1.png") 
print(img)
# Out:
# [[[199 158 109]
#   [199 158 109]
#   [199 158 109]
#   ...,
#   [197 156 111]
#   [194 153 108]
#   [189 148 103]]
#
#  [[199 158 109]
#   [199 158 109]
#   [199 158 109]
#   ...,
#   [197 156 111]
#   [194 153 108]
#   [190 149 104]]
#
#  [[199 158 109]
#   [199 158 109]
#   [199 158 109]
#   ...,
#   [197 156 111]
#   [194 153 108]
#   [190 149 104]]
#
#  ...,
#  [[ 95  88  85]
#   [ 95  88  85]
#   [ 95  88  85]
#   ...,
#   [ 91  81  81]
#   [ 90  80  80]
#   [ 89  79  79]]
#
#  [[ 94  86  86]
#   [ 94  86  86]
#   [ 95  87  87]
#   ...,
#   [ 89  80  77]
#   [ 89  80  77]
#   [ 88  79  76]]
#
#  [[ 92  84  84]
#   [ 92  84  84]
#   [ 92  84  84]
#   ...,
#   [ 90  78  76]
#   [ 89  77  75]
#   [ 88  76  74]]]

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (540, 960, 3)

# %%
import numpy as np
image_copy = np.copy(img)
image_copy2 = np.copy(img)
plt.imshow(image_copy)
plt.show()

# %%
type(image_copy)
# Out:
# numpy.ndarray

# %%
image_copy.shape
# Out:
# (540, 960, 3)

# %%
red_thre = 200;
green_thre = 200;
blue_thre = 200;
rgb_thre = [red_thre,green_thre,blue_thre]
thre = (img[:,:,0] < rgb_thre[0]) | (img[:,:,1] < rgb_thre[1]) |  (img[:,:,2] < rgb_thre[2])

# %%
print(thre)
# Out:
# [[False False False ..., False False False]
#  [False False False ..., False False False]
#  [False False False ..., False False False]
#  ...,
#  [False False False ..., False False False]
#  [False False False ..., False False False]
#  [False False False ..., False False False]]

# %%
type(thre)
# Out:
# numpy.ndarray

# %%
thre.shape
# Out:
# (540, 960)

# %%
image_copy2[thre] = [0,0,0]

# %%
print(image_copy2)
# Out:
# [[[200 200   0]
#   [200 200   0]
#   [200 200   0]
#   ...,
#   [200 200   0]
#   [200 200   0]
#   [200 200   0]]
#
#  [[200 200   0]
#   [200 200   0]
#   [200 200   0]
#   ...,
#   [200 200   0]
#   [200 200   0]
#   [200 200   0]]
#
#  [[200 200   0]
#   [200 200   0]
#   [200 200   0]
#   ...,
#   [200 200   0]
#   [200 200   0]
#   [200 200   0]]
#
#  ...,
#  [[200 200   0]
#   [200 200   0]
#   [200 200   0]
#   ...,
#   [200 200   0]
#   [200 200   0]
#   [200 200   0]]
#
#  [[200 200   0]
#   [200 200   0]
#   [200 200   0]
#   ...,
#   [200 200   0]
#   [200 200   0]
#   [200 200   0]]
#
#  [[200 200   0]
#   [200 200   0]
#   [200 200   0]
#   ...,
#   [200 200   0]
#   [200 200   0]
#   [200 200   0]]]

# %%
image_copy2.shape
# Out:
# (540, 960, 3)

# %%
plt.imshow(image_copy2)
plt.show()

# %%
'''
changing values of thre to 200
'''
red_thre = 200;
green_thre = 200;
blue_thre = 200;
rgb_thre = [red_thre,green_thre,blue_thre]
thre = (img[:,:,0] < rgb_thre[0]) | (img[:,:,1] < rgb_thre[1]) |  (img[:,:,2] < rgb_thre[2])
print(thre)
# Out:
# [[ True  True  True ...,  True  True  True]
#  [ True  True  True ...,  True  True  True]
#  [ True  True  True ...,  True  True  True]
#  ...,
#  [ True  True  True ...,  True  True  True]
#  [ True  True  True ...,  True  True  True]
#  [ True  True  True ...,  True  True  True]]

# %%
image_copy[thre] = [200,200,0]
print(image_copy)
plt.imshow(image_copy)
plt.show()
# Out:
# [[[200 200   0]
#   [200 200   0]
#   [200 200   0]
#   ...,
#   [200 200   0]
#   [200 200   0]
#   [200 200   0]]
#
#  [[200 200   0]
#   [200 200   0]
#   [200 200   0]
#   ...,
#   [200 200   0]
#   [200 200   0]
#   [200 200   0]]
#
#  [[200 200   0]
#   [200 200   0]
#   [200 200   0]
#   ...,
#   [200 200   0]
#   [200 200   0]
#   [200 200   0]]
#
#  ...,
#  [[200 200   0]
#   [200 200   0]
#   [200 200   0]
#   ...,
#   [200 200   0]
#   [200 200   0]
#   [200 200   0]]
#
#  [[200 200   0]
#   [200 200   0]
#   [200 200   0]
#   ...,
#   [200 200   0]
#   [200 200   0]
#   [200 200   0]]
#
#  [[200 200   0]
#   [200 200   0]
#   [200 200   0]
#   ...,
#   [200 200   0]
#   [200 200   0]
#   [200 200   0]]]

# %%
plt.imshow(image_copy)
plt.show()

# %%
'''
Canny Edge Detection
'''

image2 = cv2.imread("C:/Users/Kathu/Desktop/SJSU/Second Sem/ML - CMPE 257/Python files/car.jpg") 
plt.imshow(image2)
plt.show()
edges = cv2.Canny(image2,100,200)
plt.imshow(edges)
plt.show()
